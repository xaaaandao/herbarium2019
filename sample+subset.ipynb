# %%
import pathlib

# %%
local_folder = "/mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-train+labeled"

# %%
genus = [f.name.split("+")[0] for f in pathlib.Path(local_folder).iterdir()]
genus = list(set(genus))
genus
# Out:
# ['Monochaetum',
#  'Tetrazygia',
#  'Monolena',
#  'Pleiochiton',
#  'Chaetolepis',
#  'Heterocentron',
#  'Ossaea',
#  'Brachyotum',
#  'Aciotis',
#  'Lavoisiera',
#  'Meriania',
#  'Acisanthera',
#  'Mecranium',
#  'Pachyloma',
#  'Phainantha',
#  'Cambessedesia',
#  'Charianthus',
#  'Castratella',
#  'Opisthocentra',
#  'Microlicia',
#  'Siphanthera',
#  'Adelobotrys',
#  'Pilocosta',
#  'Henriettea',
#  'Bellucia',
#  'Maieta',
#  'Tococa',
#  'Rhynchanthera',
#  'Appendicularia',
#  'Ernestia',
#  'Desmoscelis',
#  'Centradenia',
#  'Miconia',
#  'Comolia',
#  'Mouriri',
#  'Nepsera',
#  'Chaetostoma',
#  'Axinaea',
#  'Huberia',
#  'Macairea',
#  'Trembleya',
#  'Rhexia',
#  'Macrocentrum',
#  'Pterogastra',
#  'Sandemania',
#  'Bucquetia',
#  'Pterolepis',
#  'Clidemia',
#  'Marcetia',
#  'Noterophila',
#  'Arthrostemma',
#  'Conostegia',
#  'Graffenrieda',
#  'Salpinga',
#  'Purpurella',
#  'Schwackaea',
#  'Triolena',
#  'Tibouchina',
#  'Blakea',
#  'Centronia',
#  'Acanthella',
#  'Tateanthus',
#  'Leandra']

# %%
count_of_genus = 5

# %%
import numpy as np

rng = np.random.default_rng(seed=42) # Usando a seed que vimos anteriormente!

choices = rng.choice(genus, size=count_of_genus, replace=False)
print(choices)
# Out:
# ['Pterolepis' 'Rhynchanthera' 'Macairea' 'Heterocentron' 'Leandra']

# %%
import os

for p in ["/mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-train+labeled", "/mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation+labeled"]:
    dst = os.path.join(p+f"+subset+genus={count_of_genus}")
    os.makedirs(dst, exist_ok=True)
    for c in choices:
        cmd = f"cp -r {os.path.join(p, c)}* {dst}"
        os.system(cmd)

# %% [markdown]
# # Os valores:
# - devem ser iguais
# - representam a quantidade de espécies

# %%
for p in ["/mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-train+labeled", "/mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation+labeled"]:
    dst = os.path.join(p+f"+subset+genus={count_of_genus}")
    print(dst, len(os.listdir(dst)))
# Out:
# /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-train+labeled+subset+genus=5 67
# /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation+labeled+subset+genus=5 67
