# %%
import os
import pathlib

from PIL import Image

# %%
for d in ['/mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation+labeled-balanced+min=50']:
    for p in pathlib.Path(d).rglob('*.jpg'):
        size = (512, 512)
        dst = d + '-512x512'
        os.makedirs(os.path.join(dst, p.parent.name), exist_ok=True)
        filename = os.path.join(dst, p.parent.name, p.name)
        print(f"dst: {filename}")
        img = Image.open(p)
        largura_original, altura_original = img.size

        # Nova largura desejada
        # nova_largura = 300

        # Calcula a altura proporcional
        # proporcao = nova_largura / largura_original
        # nova_altura = int(altura_original * proporcao)

        # Redimensiona usando o novo tamanho proporcional
        img_redimensionada = img.resize(size, Image.Resampling.LANCZOS)
        img_redimensionada.save(filename)
# Out:
# dst: /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation+labeled-balanced+min=50-512x512/Miconia+laevigata/00023.jpg
# dst: /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation+labeled-balanced+min=50-512x512/Miconia+laevigata/00176.jpg
# dst: /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation+labeled-balanced+min=50-512x512/Miconia+laevigata/00118.jpg
# dst: /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation+labeled-balanced+min=50-512x512/Miconia+laevigata/00207.jpg
# dst: /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation+labeled-balanced+min=50-512x512/Conostegia+montana/00015.jpg
# dst: /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation+labeled-balanced+min=50-512x512/Conostegia+montana/00007.jpg
# dst: /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation+labeled-balanced+min=50-512x512/Conostegia+montana/00053.jpg
# ...
