# %%
labels = !ls /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-train+labeled-balanced+min=50-512x512

# %%
labels = [l for l in labels if "+" in l]

# %%
import pandas as pd
df = pd.DataFrame([item.split("+") for item in labels], columns=["genero", "especie"])
df.head()
# Out:
#         genero       especie
# 0      Aciotis  acuminifolia
# 1      Aciotis    caulialata
# 2      Aciotis      indecora
# 3      Aciotis  purpurascens
# 4  Acisanthera      quadrata

# %%
df["genero"].unique()
# Out:
# <StringArray>
# [      'Aciotis',   'Acisanthera',   'Adelobotrys',  'Arthrostemma',
#        'Axinaea',      'Bellucia',        'Blakea',    'Brachyotum',
#  'Cambessedesia',   'Centradenia',   'Chaetolepis',      'Clidemia',
#        'Comolia',    'Conostegia',   'Desmoscelis',    'Henriettea',
#        'Leandra',      'Macairea',        'Maieta',      'Marcetia',
#      'Mecranium',      'Meriania',       'Miconia',   'Monochaetum',
#        'Mouriri',       'Nepsera',    'Pterolepis',        'Rhexia',
#  'Rhynchanthera',      'Salpinga',   'Siphanthera',    'Tetrazygia',
#     'Tibouchina',        'Tococa',     'Trembleya']
# Length: 35, dtype: str
