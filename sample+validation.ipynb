# %%
import os
import pandas as pd

# %%
local_file = "/mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/categories.txt"

# %%
df = pd.read_csv(local_file)
df.head()
# Out:
#    Category                      ScientificName
# 0         0  Miconia approximata Gamba & Almeda
# 1         1  Miconia ibaguensis (Bonpl.) Triana
# 2         2          Leandra nianga (DC.) Cogn.
# 3         3       Tibouchina semidecandra Cogn.
# 4         4        Miconia racemosa (Aubl.) DC.

# %%
df["folder_name"] = df["ScientificName"].str.split(" ").str[0] + "+" + df["ScientificName"].str.split(" ").str[1]
df.head()
# Out:
#    Category                      ScientificName              folder_name
# 0         0  Miconia approximata Gamba & Almeda      Miconia+approximata
# 1         1  Miconia ibaguensis (Bonpl.) Triana       Miconia+ibaguensis
# 2         2          Leandra nianga (DC.) Cogn.           Leandra+nianga
# 3         3       Tibouchina semidecandra Cogn.  Tibouchina+semidecandra
# 4         4        Miconia racemosa (Aubl.) DC.         Miconia+racemosa

# %%
base_dir = "/mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation"

# %%
import pathlib

for p in pathlib.Path(base_dir).glob("*"):
    src = os.path.join(p)
    mask = df["Category"] == int(p.name)
    label = df.loc[mask, "folder_name"].values[0]
    dst = os.path.join(p.parent, label)
    # os.makedirs(dst, exist_ok=True)
    os.system(f"mv \"{src}\" \"{dst}\"")

    print(f"src {src}")
    print(f"dst {dst}")
# Out:
# src /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/382
# dst /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Miconia+rubiginosa
# src /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/227
# dst /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Rhexia+alifanus
# src /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/101
# dst /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Tibouchina+laxa
# src /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/17
# dst /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Graffenrieda+harlingii
# src /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/368
# dst /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Aciotis+rubricaulis
# src /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/624
# ...

# %% [markdown]
# # Removo espécies que tem mais de uma subespécie

# %%
import shutil

for l in os.listdir(base_dir):
    for l2 in os.listdir(os.path.join(base_dir, l)):
        if os.path.isdir(os.path.join(base_dir, l, l2)):
            print(f"removido {os.path.join(base_dir, l)}")
            shutil.rmtree(os.path.join(base_dir, l))
# Out:
# removido /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Clidemia+ciliata
# removido /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Miconia+ceramicarpa
# removido /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Miconia+impetiolaris
# removido /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Miconia+argyrophylla
# removido /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Clidemia+capitellata
# removido /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Clidemia+octona
# removido /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Mecranium+integrifolium
# removido /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Miconia+theaezans
# removido /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Rhexia+mariana
# removido /mnt/eec07521-c36a-4d2b-9047-0110e7749eae/TAN2019/small-validation/Mouriri+myrtilloides
# ...

# %%
for l in os.listdir(base_dir):
    for l2 in os.listdir(os.path.join(base_dir, l)):
        if os.path.isdir(os.path.join(base_dir, l, l2)):
            print(f"diretorio {os.path.join(base_dir, l)} tem pasta")

# %% [markdown]
# # Inicialmente, o dataset tinha 683 subespécies, após o processamento ele ficou com 659 espécies
